# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 0863-F8A2
#
#  Directory of C:\Users\Asus
#
# 19/04/2022  00:10    <DIR>          .
# 29/01/2022  18:20    <DIR>          ..
# 02/04/2022  16:01    <DIR>          .anaconda
# 19/04/2022  00:27    <DIR>          .conda
# 02/04/2022  16:00                25 .condarc
# 02/04/2022  16:00    <DIR>          .continuum
# 31/03/2020  15:07    <DIR>          .idlerc
# 18/04/2022  23:57    <DIR>          .ipynb_checkpoints
# 02/04/2022  16:23    <DIR>          .ipython
# 19/04/2022  00:22    <DIR>          .jupyter
# 28/02/2021  17:13    <DIR>          .LINE
# 18/04/2022  23:53    <DIR>          .matplotlib
# 28/02/2021  17:13    <DIR>          .QtWebEngineProcess
# 15/12/2021  12:00    <DIR>          .vscode
# 15/10/2020  01:09    <DIR>          3D Objects
# 02/04/2022  16:03    <DIR>          anaconda3
# 07/02/2020  16:54    <DIR>          ansel
# 21/10/2020  21:03    <DIR>          Autodesk
# ...

# %%
df = pd.read_csv('Downloads/Data_manipulation/telco_customer_churn.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['tenure'].describe()
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64

# %%
df[(df['tenure'] >55) | (df['MonthlyCharges'] > 70)]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# ...          ...     ...            ...     ...        ...     ...
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 4             Yes            No     Fiber optic                   No  ...
# ...

# %%
 df.groupby(['gender'])['customerID'].count()
# Out:
# gender
# Female    3488
# Male      3555
# Name: customerID, dtype: int64

# %%
 df.groupby(['InternetService'])['customerID'].count()
# Out:
# InternetService
# DSL            2421
# Fiber optic    3096
# No             1526
# Name: customerID, dtype: int64

# %%
 df.groupby(['PaymentMethod'])['customerID'].count()
# Out:
# PaymentMethod
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Electronic check             2365
# Mailed check                 1612
# Name: customerID, dtype: int64

# %%
df['MonthlyCharges_level'] = pd.cut(df['MonthlyCharges'],
                                    bins=[0,35.5,70.5,89.9,999],
                                    labels=['Low','Medium','High','Very High'])

# %%
df[['MonthlyCharges','MonthlyCharges_level']]
# Out:
#       MonthlyCharges MonthlyCharges_level
# 0              29.85                  Low
# 1              56.95               Medium
# 2              53.85               Medium
# 3              42.30               Medium
# 4              70.70                 High
# ...              ...                  ...
# 7038           84.80                 High
# 7039          103.20            Very High
# 7040           29.60                  Low
# 7041           74.40                 High
# 7042          105.65            Very High
#
# [7043 rows x 2 columns]

# %%
df[['MonthlyCharges','MonthlyCharges_level']].head(20)
# Out:
#     MonthlyCharges MonthlyCharges_level
# 0            29.85                  Low
# 1            56.95               Medium
# 2            53.85               Medium
# 3            42.30               Medium
# 4            70.70                 High
# 5            99.65            Very High
# 6            89.10                 High
# 7            29.75                  Low
# 8           104.80            Very High
# 9            56.15               Medium
# 10           49.95               Medium
# 11           18.95                  Low
# 12          100.35            Very High
# 13          103.70            Very High
# 14          105.50            Very High
# 15          113.25            Very High
# 16           20.65                  Low
# 17          106.70            Very High
# 18           55.20               Medium
# 19           90.05            Very High
